# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
satyam=pd.read_csv(r"C:\Users\user\Downloads\Indian Premier League\matches.csv")

# %%
satyam.head(4)
# Out:
#    id  season       city        date                   team1  \
# 0   1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# ...

# %%
satyam.shape
# Out:
# (756, 18)

# %%
satyam.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
satyam.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
satyam.dtypes.value_counts()
# Out:
# object    13
# int64      5
# dtype: int64

# %%
satyam.season.unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
satyam.season.nunique()
# Out:
# 12

# %%
satyam.count()
# Out:
# id                 756
# season             756
# city               749
# date               756
# team1              756
# team2              756
# toss_winner        756
# toss_decision      756
# result             756
# dl_applied         756
# winner             752
# win_by_runs        756
# win_by_wickets     756
# player_of_match    752
# venue              756
# umpire1            754
# umpire2            754
# umpire3            119
# dtype: int64

# %%
satyam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Q1). Most "Man of the match" Awards.

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
satyam.player_of_match.value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: player_of_match, Length: 226, dtype: int64

# %% [markdown]
# # Q2). Only names of ''Top 10 players''.

# %%
list(satyam['player_of_match'].value_counts()[0:10].keys())
# Out:
# ['CH Gayle',
#  'AB de Villiers',
#  'RG Sharma',
#  'MS Dhoni',
#  'DA Warner',
#  'YK Pathan',
#  'SR Watson',
#  'SK Raina',
#  'G Gambhir',
#  'MEK Hussey']

# %% [markdown]
# # Q3). Number of awards of "top 10 players".

# %%
list(satyam['player_of_match'].value_counts()[0:10])
# Out:
# [21, 20, 17, 17, 17, 16, 15, 14, 13, 12]

# %% [markdown]
# # Q4). Create a Bar Plot for "top 10 players" with most "man of the match awards".

# %%
plt.figure(figsize=(20,10))
plt.bar(list(satyam['player_of_match'].value_counts()[0:10].keys()), list(satyam['player_of_match'].value_counts()[0:10]), color='r')
plt.xlabel("Top 10 Players")
plt.ylabel("No. of man of the match")
plt.show()

# %% [markdown]
# # Observations-
#
# ## 1. Cris Gale got highest number of "man of the match" award.
#
# ## 2. Mike Hussey is least in Top 10 list of "man of the match" award.

# %% [markdown]
# # Q5). Frequency of Result column.

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam.result.value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %% [markdown]
# # Q6). Most toss win.

# %%
satyam.toss_winner.value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %% [markdown]
# # Q7). Extract the records where a team bat first and win the game.

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam[satyam.win_by_runs!=0]
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4        5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8        9    2017       Pune  2017-04-11             Delhi Daredevils
# 13      14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14      15    2017      Delhi  2017-04-15             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi    28/04/19               Delhi Capitals
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19          Sunrisers Hyderabad
# 745  11341    2019    Chennai    01/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # Q7). Find out the number of wins with respect to each team after batting.

# %%
satyam[satyam.win_by_runs!=0].winner.value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # Q8). Making a bar plot for Top 5 teams with Most wins after first batting.

# %%
list(satyam[satyam.win_by_runs!=0].winner.value_counts().keys()[0:5])
# Out:
# ['Mumbai Indians',
#  'Chennai Super Kings',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore']

# %%
list(satyam[satyam.win_by_runs!=0].winner.value_counts())[0:5]
# Out:
# [57, 52, 38, 36, 35]

# %%
plt.figure(figsize=(15,10))
plt.bar(list(satyam[satyam.win_by_runs!=0].winner.value_counts().keys()[0:5]), list(satyam[satyam.win_by_runs!=0].winner.value_counts())[0:5], color=['r', 'y', 'g', 'b'])
plt.show()

# %% [markdown]
# # Q9). Making a pie chart for  teams with Most wins after first batting.

# %%
plt.figure(figsize=(10,10))
plt.pie(list(satyam[satyam.win_by_runs!=0].winner.value_counts()), labels=list(satyam[satyam.win_by_runs!=0].winner.value_counts().keys()), autopct='%0.0f%%')
plt.show()

# %% [markdown]
# # Observation-
#
# ## Mumbai Indians get most wins after taking first batting.
# ## Gujrat Lions get least wins after taking batting.

# %% [markdown]
# # Q10). Extracting records where a team has won after batting second.

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam[satyam.win_by_wickets!=0]
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # Q11). Making a histogram for frequency of wins w.r.t. number of wickets.

# %%
plt.figure(figsize=(10,10))
plt.hist(satyam[satyam.win_by_wickets!=0].win_by_wickets)
plt.xlabel("No. of wickets")
plt.ylabel("No. of win matchs")
plt.show()

# %% [markdown]
# # Q12). Make a Bar graph of Top 3 teams win match after second batting.

# %%
satyam[satyam.win_by_wickets!=0].winner.value_counts().keys()[0:3]
# Out:
# Index(['Kolkata Knight Riders', 'Mumbai Indians',
#        'Royal Challengers Bangalore'],
#       dtype='object')

# %%
list(satyam[satyam.win_by_wickets!=0].winner.value_counts())[0:3]
# Out:
# [56, 50, 48]

# %%
plt.figure(figsize=(10,4))
plt.bar(satyam[satyam.win_by_wickets!=0].winner.value_counts().keys()[0:3], list(satyam[satyam.win_by_wickets!=0].winner.value_counts())[0:3], color=['r', 'g', 'b'])
plt.xlabel("Team")
plt.ylabel("Matches wins")
plt.grid()
plt.show()

# %% [markdown]
# # Q13). Make a pie chart for distribution of most wins after second batting.

# %%
satyam[satyam.win_by_wickets!=0].winner.value_counts().keys()
# Out:
# Index(['Kolkata Knight Riders', 'Mumbai Indians',
#        'Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Gujarat Lions', 'Deccan Chargers',
#        'Pune Warriors', 'Delhi Capitals', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.pie(satyam[satyam.win_by_wickets!=0].winner.value_counts(), labels=satyam[satyam.win_by_wickets!=0].winner.value_counts().keys(),autopct='%0.2f%%')
plt.show()

# %% [markdown]
# ## Observation-
#
# ### 1). Kolkata Knight riders make most win on second batting.
# ### 2). Rising Pune Supergiants make least win on second batting.

# %% [markdown]
# # Q14). Total number of matches in each season.

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# # Q15). Total number of matches in each cities.

# %%
satyam.city.value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %% [markdown]
# # Q16). Make a bar plot for Top-10 cities hosting most number of the matches.

# %%
satyam.city.value_counts().keys()[0:10]
# Out:
# Index(['Mumbai', 'Kolkata', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai',
#        'Jaipur', 'Chandigarh', 'Pune', 'Durban'],
#       dtype='object')

# %%
list(satyam.city.value_counts())[0:10]
# Out:
# [101, 77, 74, 66, 64, 57, 47, 46, 38, 15]

# %%
plt.figure(figsize=(20,10))
plt.bar(satyam.city.value_counts().keys()[0:10], list(satyam.city.value_counts())[0:10], color= ["red", "y", "g", "b","navy"])
plt.show()

# %% [markdown]
# ## Observation-
#
# ### 1). Mumbai has hosted most number of matches.
# ### 2). Durban has hosted least number of matches among Top 10 cities.

# %% [markdown]
# # Impact of toss--

# %% [markdown]
# # Q17). Finding out how many times a team won the match after winning toss?

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam[satyam.toss_winner==satyam.winner]
# Out:
#         id  season           city        date                        team1  \
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# ..     ...     ...            ...         ...                          ...
# 750  11346    2019         Mohali    05/05/19          Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
satyam[satyam.toss_winner==satyam.winner].shape
# Out:
# (393, 18)

# %%
import numpy as np
np.sum(satyam.toss_winner==satyam.winner)
# Out:
# 393

# %% [markdown]
# # Q18). Plot a bar graph of Top 5 teams that won the match after toss win.

# %%
satyam[satyam.toss_winner==satyam.winner].winner.value_counts()
# Out:
# Chennai Super Kings            57
# Mumbai Indians                 56
# Kolkata Knight Riders          53
# Rajasthan Royals               42
# Royal Challengers Bangalore    41
# Kings XI Punjab                35
# Delhi Daredevils               35
# Sunrisers Hyderabad            23
# Deccan Chargers                19
# Gujarat Lions                  10
# Delhi Capitals                  7
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.bar(satyam[satyam.toss_winner==satyam.winner].winner.value_counts().keys()[0:5], list(satyam[satyam.toss_winner==satyam.winner].winner.value_counts()[0:5]), color=["gold", "b", "m", "navy", "r"])
plt.show()

# %% [markdown]
# # Q19). Plot a pie chart for percentage of match win after toss win.

# %%
plt.figure(figsize=(10,10))
plt.pie(satyam[satyam.toss_winner==satyam.winner].winner.value_counts(), labels=satyam[satyam.toss_winner==satyam.winner].winner.value_counts().keys(), autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ## Observation-
# ### 1). CSK won most matches after winning toss.
# ### 2). Rising pune supergiants won least matches after winning toss.

# %% [markdown]
# # Toss decission-

# %%
satyam.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
satyam.toss_decision.value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# # Q20). Plot a pie chart to visualize what is the percentage of Decision to Bat or Field.

# %%
plt.figure(figsize=(5,5))
plt.pie(list(satyam.toss_decision.value_counts()),labels=satyam.toss_decision.value_counts().keys(), autopct="%0.2f%%")
plt.show()

# %%
satyam[satyam.toss_decision=="field"].season.value_counts()
# Out:
# 2018    50
# 2019    50
# 2016    49
# 2017    48
# 2011    48
# 2014    41
# 2012    37
# 2015    34
# 2008    32
# 2013    31
# 2009    22
# 2010    21
# Name: season, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.bar(list(satyam[satyam.toss_decision=="field"].season.value_counts().keys()), list(satyam[satyam.toss_decision=="field"].season.value_counts()), label="field", width=0.4)
plt.bar(list(satyam[satyam.toss_decision=="bat"].season.value_counts().keys()), list(satyam[satyam.toss_decision=="bat"].season.value_counts()), label="bat", width=0.4)
plt.legend()
plt.show()

# %% [markdown]
# # Exploring deliveries dataset--

# %%
shivam=pd.read_csv(r"C:\Users\user\Downloads\Indian Premier League\deliveries.csv")

# %%
shivam.tail(10)
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179068     11415       2  Chennai Super Kings  Mumbai Indians    19     3
# 179069     11415       2  Chennai Super Kings  Mumbai Indians    19     4
# 179070     11415       2  Chennai Super Kings  Mumbai Indians    19     5
# 179071     11415       2  Chennai Super Kings  Mumbai Indians    19     6
# 179072     11415       2  Chennai Super Kings  Mumbai Indians    20     1
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179068  RA Jadeja   SR Watson   JJ Bumrah              0  ...         0
# ...

# %% [markdown]
# # Q21). Finding total number of fours and six hit by each team.

# %%
shivam[shivam.batsman_runs==4].batting_team.value_counts()
# Out:
# Mumbai Indians                 2588
# Kings XI Punjab                2458
# Kolkata Knight Riders          2434
# Royal Challengers Bangalore    2360
# Chennai Super Kings            2193
# Delhi Daredevils               2158
# Rajasthan Royals               2035
# Sunrisers Hyderabad            1444
# Deccan Chargers                 957
# Pune Warriors                   525
# Gujarat Lions                   460
# Delhi Capitals                  242
# Rising Pune Supergiant          197
# Rising Pune Supergiants         171
# Kochi Tuskers Kerala            170
# Name: batting_team, dtype: int64

# %%
shivam[shivam.batsman_runs==6].batting_team.value_counts()
# Out:
# Royal Challengers Bangalore    1132
# Mumbai Indians                 1096
# Kings XI Punjab                 976
# Chennai Super Kings             973
# Kolkata Knight Riders           930
# Delhi Daredevils                801
# Rajasthan Royals                681
# Sunrisers Hyderabad             533
# Deccan Chargers                 400
# Pune Warriors                   196
# Gujarat Lions                   155
# Rising Pune Supergiant           89
# Delhi Capitals                   87
# Rising Pune Supergiants          68
# Kochi Tuskers Kerala             53
# Name: batting_team, dtype: int64

# %% [markdown]
# # Q22). Most no. of boundaries hit by each team.

# %%
shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batting_team.value_counts()
# Out:
# Mumbai Indians                 3684
# Royal Challengers Bangalore    3492
# Kings XI Punjab                3434
# Kolkata Knight Riders          3364
# Chennai Super Kings            3166
# Delhi Daredevils               2959
# Rajasthan Royals               2716
# Sunrisers Hyderabad            1977
# Deccan Chargers                1357
# Pune Warriors                   721
# Gujarat Lions                   615
# Delhi Capitals                  329
# Rising Pune Supergiant          286
# Rising Pune Supergiants         239
# Kochi Tuskers Kerala            223
# Name: batting_team, dtype: int64

# %%
plt.figure(figsize=(40,20))
plt.bar(shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batting_team.value_counts().keys(), list(shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batting_team.value_counts()))
plt.xlabel("Teams", fontsize=40)
plt.ylabel("Bounderies", fontsize=40)
plt.title("Most Bounderies", fontsize=50)
plt.xticks(rotation=65, fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# # Q23). Finding the TOP 10 Batsman hitting maximum number of bounderies.

# %%
shivam.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batsman.value_counts().head(10)
# Out:
# CH Gayle          703
# SK Raina          690
# V Kohli           673
# DA Warner         640
# RG Sharma         625
# S Dhawan          622
# RV Uthappa        592
# AB de Villiers    571
# G Gambhir         551
# SR Watson         521
# Name: batsman, dtype: int64

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize=(20,10))
plt.bar(shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batsman.value_counts().head(10).keys(), list(shivam[(shivam.batsman_runs==6) | (shivam.batsman_runs==4)].batsman.value_counts().head(10)))
plt.xlabel("Players", fontsize= 30)
plt.ylabel("Total Bounderies", fontsize=30)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Observation--
# ### Gayle hit maximum bounderies.

# %% [markdown]
# # Q24). Top 10 Batsman scoring maximum numbers of runs.

# %%
shivam.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
shivam.groupby("batsman")["batsman_runs"].agg([("Runs", "sum")]).sort_values("Runs", ascending= False).head(10)
# Out:
#                 Runs
# batsman
# V Kohli         5434
# SK Raina        5415
# RG Sharma       4914
# DA Warner       4741
# S Dhawan        4632
# CH Gayle        4560
# MS Dhoni        4477
# RV Uthappa      4446
# AB de Villiers  4428
# G Gambhir       4223

# %% [markdown]
# # Making a Bar Plot to find Top 10 Batsman Scoring Most runs.

# %%
shivam.groupby("batsman")["batsman_runs"].agg([("Runs", "sum")]).sort_values("Runs", ascending= False).head(10).plot.bar()
plt.show()

# %% [markdown]
# # Observation--
# ## 1) Virat kohli scored most run in the tournamnet.
# ## 2) Raina is second highest scorer in the tournament.
# ## 3) Gambhir scored least run in tournament.

# %% [markdown]
# # Q25). Top 5 bowlers.

# %%
shivam.head(20)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
shivam[shivam.player_dismissed.notnull()].bowler.value_counts().head(5)
# Out:
# SL Malinga         188
# DJ Bravo           168
# A Mishra           165
# Harbhajan Singh    161
# PP Chawla          156
# Name: bowler, dtype: int64

# %% [markdown]
# # SUMMERY--
# ## 1). Mumbai indians, CSK, and KKR are the most successfull team in IPL Tournament.
# ## 2). Win the toss and field first has been the trend in the recent times.(61%)
# ## 3). Gayle won most man of the match award.
# ## 4). Shikhar dhawan hammered most number of 4's and Galye hammerd most number of 6's.
# ## 5). Virat Kohli is the most run scorer of the ipl tournament.
# ## 6). Lasit Mallinga is the lead wicket taker in ipl tournament.
# ## 7). Companies should go to any of from MI, CSK and KKR to endorse their product.
# ## 8). Companies should go to any of from Virat kohli, Gayle, Lasit mallinga, Suresh Raina, Shikhar Dhawan, and Dhoni for the endorsement of their product.
